# %%
import numpy as np
import matplotlib.pyplot as plt
from utils.opt_utils import *
import h5py
import pickle
from qutip import *
import time
import tqdm

# %%
wc_A = 4.069814 * (10**9) * 2 * np.pi  # cavity A frequency
wc_B = 6.096062 * (10**9) * 2 * np.pi  # cavity A frequency
wa =  5.325 * (10**9) * 2 * np.pi  # atom frequency
dt_A = np.abs(wc_A - wa) / (2 * np.pi)
dt_B = np.abs(wc_B - wa) / (2 * np.pi)
chi_A = 0.00215 * (10**9) * 2 * np.pi
chi_B = 0.00544 * (10**9) * 2 * np.pi
g_A = np.sqrt(chi_A * dt_A) * 2 * np.pi  # coupling strength w/ cavity A
g_B = np.sqrt(chi_B * dt_B) * 2 * np.pi  # coupling strength w/ cavity B

gamma = 333333.333        # atom dissipation rate
kappa_A = 10000       # cavity A dissipation rate
kappa_B = 10000       # cavity B dissipation rate

temp_q = 0.01        # avg number of thermal bath excitation for qubit
temp_A = 0.04        # avg number of thermal bath excitation for cavity A
temp_B = 0.05        # avg number of thermal bath excitation for cavity B

# %%
cavity_dims = 8

def cost_q_e(final_expect, final_state):
    return  np.power(np.abs(final_state[cavity_dims]), 2)

def cost_qA_g1(final_expect, final_state):
    return np.power(np.abs(final_state[1][0]), 2)

# %%
max_segs = 20
us = 0.000001
time_start = 0.0000000
time_stop = 2.25 * us
init_amp = 4000000
n_steps = 501


num_drives = 2
num_elems = 2
num_cavities = 1
# cavity_dims = 8
state_sizes = [2, cavity_dims]
state_vals = [0, 0]
sim_options = Options()
element_freqs = [wa, wc_A]
output_cost_func = cost_qA_g1
verbose = True


t_arr = np.linspace(time_start, time_stop, n_steps)

t_step = (time_stop - time_start) / n_steps

sim_options.store_final_state = True

sm, a_A, a_B, sx, sz = reg_ops(num_cavities + 1, cavity_dims)
drive_freqs = np.array(element_freqs)

gammas = [gamma, kappa_A]
temps = [temp_q, temp_A]
c_ops = [] # gen_c_ops(elements, [sm, a_A, a_B, sx, sz], gammas, temps)

# Operators used in Hamiltonian
drive_ops = [sm.dag(), sm, a_A.dag(), a_A]
element_ops = [sz, a_A.dag() * a_A]
H_0 = (chi_A * a_A.dag() * a_A * sz / 2)
eval_ops = [sm.dag() * sm, a_A.dag() * a_A]

init_state = tensor((basis(state_sizes[0], 0) * np.sqrt(1 - state_vals[0])) + (basis(state_sizes[0], 1) * np.sqrt(state_vals[0])), (basis(state_sizes[1], 0) * np.sqrt(1 - state_vals[1])) + (basis(state_sizes[1], 1) * np.sqrt(state_vals[1])))

client_args = [num_drives, drive_ops, element_freqs, H_0, init_state, t_arr, eval_ops, sim_options, output_cost_func, verbose, time_start, time_stop]

# %%
freqs = np.array(element_freqs)

N_segs = 20
amp_times = np.linspace(time_start, time_stop, N_segs + 1)

times = np.array([amp_times, amp_times, amp_times, amp_times])

# %%
A_i = 0
A_f = -10000000
N_amp = 21

verbose = False

client_args = [num_drives, drive_ops, element_freqs, H_0, init_state, t_arr, eval_ops, sim_options, output_cost_func, verbose, time_start, time_stop]

q1_pi_sigma = 0.20 * us
q2_pi_sigma = 0.20 * us
A1_pi_sigma = 0.05 * us
A2_pi_sigma = 0.05 * us
B1_pi_sigma = 0.05 * us
B2_pi_sigma = 0.05 * us

q1_pi_amp = 2 * 2507175
q2_pi_amp = 2 * 2507175
A1_pi_amp = 8500000
A1_pi_ampi = 0
A2_pi_amp = -2000000
A2_pi_ampi = -3000000
B1_pi_amp = 1.14 * 19600000
B1_pi_ampi = 0
B2_pi_amp = 7000000
B2_pi_ampi = 8000001

q1_time = 0.6 * us  # fixed
q2_time = 1.4 * us  # fixed
A1_time = 0.2 * us  # fixed
A2_time = 1.0 * us  # fixed
B1_time = 1.0 * us  # fixed
B2_time = 1.8 * us  # fixed

A_arr = np.linspace(A_i, A_f, N_amp)

costs = []

for A in tqdm.tqdm(A_arr):
    amp_funcs = [
        [gauss_gen(q1_pi_amp, q1_time, q1_pi_sigma, 1)], 
        [zero], 
        [gauss_gen(A1_pi_amp, A1_time, A1_pi_sigma, 1), 
         gauss_gen(A2_pi_amp, A2_time, A2_pi_sigma, 1)], 
        [gauss_gen(A2_pi_ampi, A2_time, A2_pi_sigma, 1)]
    ]
    amp_func = [func_sum(amp_funcs[i]) for i in range(len(amp_funcs))]
    
    amp_pts = np.array([amp_func[i](amp_times) for i in range(len(amp_func))])
    # print(amp_pts)
    
    for i in range(len(amp_func)):
        plt.plot(amp_times, amp_pts[i], label=f'A: {A}, drive: {i}')
    
    client_opts = np.append(np.append(amp_pts[:, 1:-1].flatten(), times[:, 1:-1].flatten()), freqs)
    
    res = sim_interp_cost_eval(client_opts, *client_args)
    costs.append(res[0])
    # print(f'Amp: {A}, cost: {res[0][0]}')
plt.show()
# Out:
#   0%|          | 0/21 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 56
#      52     plt.plot(amp_times, amp_pts[i], label=f'A: {A}, drive: {i}')
#      54 client_opts = np.append(np.append(amp_pts[:, 1:-1].flatten(), times[:, 1:-1].flatten()), freqs)
# ---> 56 res = sim_interp_cost_eval(client_opts, *client_args)
#      57 costs.append(res[0])
#      58 # print(f'Amp: {A}, cost: {res[0][0]}')
#
# File ~\Documents\GitLab\quantum_control_rl_server\utils\opt_utils.py:713, in sim_interp_cost_eval(opts, *args)
#     710 comp_amp_funcs = [func_sum(np.array(drive_amp_funcs[i])) for i in range(num_drives * 2)]
#     712 drive_camps = []
# --> 713 for i in range(0, 2 * num_drives, 2):
#     714     drive_camps.append(iq_to_amp(comp_amp_funcs[i], comp_amp_funcs[i + 1]))
#     715     drive_camps.append(iq_to_amp(comp_amp_funcs[i], comp_amp_funcs[i + 1], conj=True))
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\mesolve.py:217, in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     205 use_mesolve = ((c_ops and len(c_ops) > 0)
#     206                or (not isket(rho0))
#     207                or (isinstance(H, Qobj) and issuper(H))
#    (...)
#     213                or (not isinstance(H, (Qobj, QobjEvo)) and callable(H) and
#     214                         options.rhs_with_state))
#     216 if not use_mesolve:
# --> 217     return sesolve(H, rho0, tlist, e_ops=e_ops, args=args, options=options,
#     218                    progress_bar=progress_bar, _safe_mode=_safe_mode)
#     220 if isket(rho0):
#     221     rho0 = ket2dm(rho0)
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\sesolve.py:136, in sesolve(H, psi0, tlist, e_ops, args, options, progress_bar, _safe_mode)
#     133     v = psi0.full().ravel('F')
#     134     func(0., v, *ode_args) + v
# --> 136 res = _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, options,
#     137                          progress_bar, dims=psi0.dims)
#     138 if e_ops_dict:
#     139     res.expect = {e: res.expect[n]
#     140                   for n, e in enumerate(e_ops_dict.keys())}
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\sesolve.py:381, in _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, opt, progress_bar, dims)
#     377             output.expect[m][t_idx] = cy_expect_psi(e_ops_data[m], cdata,
#     378                                                     e_ops[m].isherm)
#     380     if t_idx < n_tsteps - 1:
# --> 381         r.integrate(r.t + dt[t_idx])
#     383 progress_bar.finished()
#     385 if opt.store_final_state:
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\scipy\integrate\_ode.py:430, in ode.integrate(self, t, step, relax)
#     427     mth = self._integrator.run
#     429 try:
# --> 430     self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     431                           self._y, self.t, t,
#     432                           self.f_params, self.jac_params)
#     433 except SystemError:
#     434     # f2py issue with tuple returns, see ticket 1187.
#     435     raise ValueError('Function to integrate must not return a tuple.')
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\scipy\integrate\_ode.py:1004, in vode.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1000     jac = _vode_banded_jac_wrapper(jac, self.ml, jac_params)
#    1002 args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1003         (f_params, jac_params))
# -> 1004 y1, t, istate = self.runner(*args)
#    1005 self.istate = istate
#    1006 if istate < 0:
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\cy\cqobjevo.pyx:212, in qutip.cy.cqobjevo.CQobjEvo.mul_vec()
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\cy\cqobjevo.pyx:679, in qutip.cy.cqobjevo.CQobjEvoTd._mul_vec()
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\cy\cqobjevo.pyx:293, in qutip.cy.cqobjevo.CQobjEvo._factor_dyn()
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\cy\cqobjevo.pyx:278, in qutip.cy.cqobjevo.CQobjEvo._factor()
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\qutip\qobjevo.py:1828, in _UnitedFuncCaller.__call__(self, t, args)
#    1826 out = []
#    1827 for func in self.funclist:
# -> 1828     out.append(func(t, now_args))
#    1829 return out
#
# File ~\Documents\GitLab\quantum_control_rl_server\utils\opt_utils.py:140, in drive_osc_camp.<locals>.drive_gen_helper(*t)
#     138 def drive_gen_helper(*t):
#     139     t = t[0]
# --> 140     return amp_func(t) * np.exp(1j * (((w0 - wd) * t) + phase_func(t)))
#
# File ~\Documents\GitLab\quantum_control_rl_server\utils\opt_utils.py:169, in iq_to_amp.<locals>.amp_helper(t)
#     168 def amp_helper(t):
# --> 169     return i_vals(t) - (1j * q_vals(t))
#
# File ~\Documents\GitLab\quantum_control_rl_server\utils\opt_utils.py:149, in func_sum.<locals>.sum_helper(t)
#     148 def sum_helper(t):
# --> 149     ret_sum = funcs[0](t)
#     150     for i, func in enumerate(funcs):
#     151         if i != 0:
#
# File ~\Documents\GitLab\quantum_control_rl_server\utils\opt_utils.py:111, in interp_seg.<locals>.pulse_helper(t)
#     109     t = np.array(t)
#     110 tc = np.zeros(np.shape(t))
# --> 111 tc[(t >= ti) & (t <= tf)] = spline(t[(t >= ti) & (t <= tf)])
#     112 return tc
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\scipy\interpolate\interpolate.py:916, in _PPolyBase.__call__(self, x, nu, extrapolate)
#     914 out = np.empty((len(x), prod(self.c.shape[2:])), dtype=self.c.dtype)
#     915 self._ensure_c_contiguous()
# --> 916 self._evaluate(x, nu, extrapolate, out)
#     917 out = out.reshape(x_shape + self.c.shape[2:])
#     918 if self.axis != 0:
#     919     # transpose to move the calculated values to the interpolation axis
#
# KeyboardInterrupt:

# %%
amp_funcs = [
        [gauss_gen(q1_pi_amp, q1_time, q1_pi_sigma, 1)], 
        [zero], 
        [gauss_gen(A1_pi_amp, A1_time, A1_pi_sigma, 1), 
         gauss_gen(A2_pi_amp, A2_time, A2_pi_sigma, 1)], 
        [gauss_gen(A2_pi_ampi, A2_time, A2_pi_sigma, 1)]
    ]
amp_func = [func_sum(amp_funcs[i]) for i in range(len(amp_funcs))]

amp_pts = np.array([amp_func[i](amp_times) for i in range(len(amp_func))])

print(f'times: {times}')
print(f't_segs shape: {np.shape(times)}')
print(f'amp_funcs: {amp_pts}')
print(f'amp shape: {np.shape(amp_pts)}')
# Out:
# times: [[0.0000e+00 1.1250e-07 2.2500e-07 3.3750e-07 4.5000e-07 5.6250e-07
#   6.7500e-07 7.8750e-07 9.0000e-07 1.0125e-06 1.1250e-06 1.2375e-06
#   1.3500e-06 1.4625e-06 1.5750e-06 1.6875e-06 1.8000e-06 1.9125e-06
#   2.0250e-06 2.1375e-06 2.2500e-06]
#  [0.0000e+00 1.1250e-07 2.2500e-07 3.3750e-07 4.5000e-07 5.6250e-07
#   6.7500e-07 7.8750e-07 9.0000e-07 1.0125e-06 1.1250e-06 1.2375e-06
#   1.3500e-06 1.4625e-06 1.5750e-06 1.6875e-06 1.8000e-06 1.9125e-06
#   2.0250e-06 2.1375e-06 2.2500e-06]
#  [0.0000e+00 1.1250e-07 2.2500e-07 3.3750e-07 4.5000e-07 5.6250e-07
#   6.7500e-07 7.8750e-07 9.0000e-07 1.0125e-06 1.1250e-06 1.2375e-06
#   1.3500e-06 1.4625e-06 1.5750e-06 1.6875e-06 1.8000e-06 1.9125e-06
#   2.0250e-06 2.1375e-06 2.2500e-06]
#  [0.0000e+00 1.1250e-07 2.2500e-07 3.3750e-07 4.5000e-07 5.6250e-07
#   6.7500e-07 7.8750e-07 9.0000e-07 1.0125e-06 1.1250e-06 1.2375e-06
#   1.3500e-06 1.4625e-06 1.5750e-06 1.6875e-06 1.8000e-06 1.9125e-06
#   2.0250e-06 2.1375e-06 2.2500e-06]]
# t_segs shape: (4, 21)
# amp_funcs: [[ 5.57053968e+04  2.57072937e+05  8.64583370e+05  2.11906753e+06
#    3.78503096e+06  4.92697830e+06  4.67388913e+06  3.23119160e+06
#    1.62792210e+06  5.97711161e+05  1.59932657e+05  3.11873642e+04
#    4.43281444e+03  4.59970636e+02  3.56397498e+01  2.90524619e+00
#    1.07636845e+00  1.00223081e+00  1.00004749e+00  1.00000074e+00
#    1.00000001e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 2.85343234e+03  1.83825592e+06  7.50122567e+06  1.93752538e+05
#    3.36765520e+01  2.00003278e+00  1.99866168e+00 -2.37225767e+02
#   -2.70668566e+05 -1.93846447e+06 -8.78718672e+04 -2.32142104e+01
#    1.99995421e+00  2.00000000e+00  2.00000000e+00  2.00000000e+00
#    2.00000000e+00  2.00000000e+00  2.00000000e+00  2.00000000e+00
#    2.00000000e+00]
#  [ 1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00
#    1.00000000e+00  1.00000000e+00  9.97992524e-01 -3.57838651e+02
#   -4.06004850e+05 -2.90769870e+06 -1.31809801e+05 -3.68213155e+01
#    9.99931308e-01  1.00000000e+00  1.00000000e+00  1.00000000e+00
#    1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00
#    1.00000000e+00]]
# amp shape: (4, 21)

# %%
np.savetxt("./opt_SNAP_times_1g.txt", times)
np.savetxt("./opt_SNAP_amps_1g.txt", amp_pts[:, 1:-1])

# %%
plt.plot(A_arr, costs)
plt.show()

# %%
plt.plot(A_arr, costs)
plt.xlabel("Displacement 2 amp")
plt.ylabel("Probability of |1g>")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 plt.plot(A_arr, costs)
#       2 plt.xlabel("Displacement 2 amp")
#       3 plt.ylabel("Probability of |1g>")
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\matplotlib\pyplot.py:3019, in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\matplotlib\axes\_axes.py:1605, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1363 """
#    1364 Plot y versus x as lines and/or markers.
#    1365
#    (...)
#    1602 (``'green'``) or hex strings (``'#008000'``).
#    1603 """
#    1604 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606 for line in lines:
#    1607     self.add_line(line)
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\matplotlib\axes\_base.py:315, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     313     this += args[0],
#     314     args = args[1:]
# --> 315 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\envs\qcrl-server\lib\site-packages\matplotlib\axes\_base.py:501, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     498     self.axes.yaxis.update_units(y)
#     500 if x.shape[0] != y.shape[0]:
# --> 501     raise ValueError(f"x and y must have same first dimension, but "
#     502                      f"have shapes {x.shape} and {y.shape}")
#     503 if x.ndim > 2 or y.ndim > 2:
#     504     raise ValueError(f"x and y can be no greater than 2D, but have "
#     505                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (21,) and (0,)

# %%
print(max(costs))
print(A_arr[np.argmax(costs)])
# Out:
# 0.7414015169098704
# -3000000.0

# %%
plt.plot(amp_times, gauss_gen(1000000, (time_start + time_stop) / 8, A1_pi_sigma, 1)(amp_times))
plt.show()
